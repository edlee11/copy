# %%
"""
2021.01.13 kaggle의 course인 "Data Visualization"이라는 프로젝트를 카피하였다.
kaggle에서 'Amazon 09-19 best seller' 데이터를 받아와 세 가지로 나누어 분석하고 그래프로 시각화하였다.
첫 번째로는 트렌드 check에 유용한 lineplot을 사용하여 시간별 추이를 확인하였다.
두 번째로는 관계성 check에 유용한 barplot을 사용하여 두 변수 간의 상관관계를 확인하였다.
세 번째로는 분포성 check에 유용한 kdeplot을 사용하여 정규분포성에 관하여 확인하였다.
"""

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
#set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
my_filepath = "C:/Users/user/Desktop/workspace/bestsellers with categories.csv"
my_data = pd.read_csv(my_filepath)
my_data.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#Check the trends
sns.lineplot(x='Year',y='Price',data=my_data)

# %%
#Check the Relationships
plt.figure(figsize=(12,6))
sns.barplot(x='User Rating', y='Reviews',data=my_data)

# %%
#Check the distribution
sns.jointplot(x=my_data['User Rating'],y=my_data['Reviews'],kind='kde')
